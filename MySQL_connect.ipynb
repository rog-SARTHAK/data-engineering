# %% [markdown]
# https://zebrabi.com/advanced-guide/how-to-integrate-mysql-into-jupyter-notebook/

# %%
from platform import python_version
print(python_version())
# Out:
# 3.11.4

# %%
# !pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/d3/b8/6798a0f91e595c0704a94c1e32a00ca930f77cb8f0f96c7e4dad4f9db1fe/mysql_connector_python-8.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/527.0 kB ? eta -:--:--
#      -------- ----------------------------- 112.6/527.0 kB 3.2 MB/s eta 0:00:01
#      ------------------ ------------------- 256.0/527.0 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 527.0/527.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.8 MB 4.5 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/10.8 MB 5.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/10.8 MB 6.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/10.8 MB 5.4 MB/s eta 0:00:02
# ...

# %%
import mysql.connector

cnx = mysql.connector.connect(user='root', password='root', host='localhost', database='demo_db')

# %%
cnx = mysql.connector.connect(user='new_hire', password='password', host='db4free.net', database='marketminds_ds', port=3306)

# %%
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()
cursor.execute("SELECT * FROM JournalEntries ORDER BY entry_id DESC LIMIT 10;")

# %%
cnx.is_connected()

cursor = cnx.cursor()
cursor.execute("SELECT * FROM JournalEntries ORDER BY entry_id DESC LIMIT 10;")

results = cursor.fetchall()
for row in results:
    print(row)
    print(len(results))
# Out:
# (494947, 4, datetime.date(2023, 8, 11), 'MRNA', '- MRNA\n  - Today, the price of MRNA updated the local lows of July 15, 2023. This happened at low trading volumes and without an aggressive reaction from buyers.\n\n  - In our previous idea, we indicated the critical point for the medium-term growth wave - this is 389.09735819107436.\n\n  - This critical point was broken by the sellers, so its time to see where to open a short position in MRNA.\n\n  - If the stop order on the long position is triggered, we will receive a profit on the short position, which will pay off the loss of the long position and the profit will still remain. An identical situation will occur if a stop order on a short position is triggered.\n\n  - Entering a short position in MRNA - Range 374.3597588729112-392.439333262746. A retest of this range will confirm the weakness of buyers. The width of this range is due to increased volatility in the market.\n\n  - Stop loss is 379.4482492578173. In our opinion, if th
# ...

# %%
cnx.is_connected()

cursor = cnx.cursor()
cursor.execute("SELECT * FROM JournalEntries ORDER BY entry_id DESC ;")

results = cursor.fetchall()


    
print(len(results))
# Out:
# 494945
